# %%
"""
BlackjackIA Experiment Notebook
================================

This notebook demonstrates the BlackjackIA project:
- Training a Q-Learning agent
- Evaluating performance
- Visualizing results
"""
